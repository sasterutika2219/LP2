# %%
import heapq

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    queue = [(0, start)]
    visited = set()

    while queue:
        (cost, node) = heapq.heappop(queue)
        if node in visited:
            continue
        visited.add(node)

        for neighbor, weight in graph[node].items():
            if neighbor not in visited:
                new_cost = distances[node] + weight
                if new_cost < distances[neighbor]:
                    distances[neighbor] = new_cost
                    heapq.heappush(queue, (new_cost, neighbor))

    return distances

# Example usage
graph = {}

n = int(input("Enter number of nodes: "))

for i in range(n):
    node = input(f"Enter name of node {i+1}: ")
    edges = {}
    while True:
        neighbor = input(f"Enter neighbor of {node} (or type 'done' to finish): ")
        if neighbor == 'done':
            break
        weight = int(input(f"Enter weight of edge between {node} and {neighbor}: "))
        edges[neighbor] = weight
    graph[node] = edges

start = input("Enter starting node: ")
distances = dijkstra(graph, start)

print(distances)
# Out:
# Enter number of nodes: 9
# Enter name of node 1: 0
# Enter neighbor of 0 (or type 'done' to finish): 1
# Enter weight of edge between 0 and 1: 4
# Enter neighbor of 0 (or type 'done' to finish): 7
# Enter weight of edge between 0 and 7: 8
# Enter neighbor of 0 (or type 'done' to finish): done
# Enter name of node 2: 1
# Enter neighbor of 1 (or type 'done' to finish): 7
# Enter weight of edge between 1 and 7: 11
# Enter neighbor of 1 (or type 'done' to finish): 2
# Enter weight of edge between 1 and 2: 8
# Enter neighbor of 1 (or type 'done' to finish): done
# Enter name of node 3: 7
# Enter neighbor of 7 (or type 'done' to finish): 8
# Enter weight of edge between 7 and 8: 7
# Enter neighbor of 7 (or type 'done' to finish): 6
# Enter weight of edge between 7 and 6: 1
# Enter neighbor of 7 (or type 'done' to finish): done
# Enter name of node 4: 6
# Enter neighbor of 6 (or type 'done' to finish): 5
# Enter weight of edge between 6 and 5: 2
# Enter neighbor of 6 (or type 'done' to finish): 8
# Enter weight of edge between 6 and 8: 6
# Enter neighbor of 6 (or type 'done' to finish): done
# Enter name of node 5: 8
# Enter neighbor of 8 (or type 'done' to finish): 2
# Enter weight of edge between 8 and 2: 2
# Enter neighbor of 8 (or type 'done' to finish): done
# Enter name of node 6: 2
# Enter neighbor of 2 (or type 'done' to finish): 3
# Enter weight of edge between 2 and 3: 7
# Enter neighbor of 2 (or type 'done' to finish): 5
# Enter weight of edge between 2 and 5: 4
# Enter neighbor of 2 (or type 'done' to finish): done
# Enter name of node 7: 5
# Enter neighbor of 5 (or type 'done' to finish): 3
# Enter weight of edge between 5 and 3: 14
# Enter neighbor of 5 (or type 'done' to finish): 4
# Enter weight of edge between 5 and 4: 10
# Enter neighbor of 5 (or type 'done' to finish): done
# Enter name of node 8: 3
# Enter neighbor of 3 (or type 'done' to finish): 4
# Enter weight of edge between 3 and 4: 9
# Enter neighbor of 3 (or type 'done' to finish): done
# Enter name of node 9: 4
# Enter neighbor of 4 (or type 'done' to finish): done
# Enter starting node: 0
# {'0': 0, '1': 4, '7': 8, '6': 9, '8': 15, '2': 12, '5': 11, '3': 19, '4': 21}
